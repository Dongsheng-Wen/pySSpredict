# %%
from sspredict.make_prediction.single_calc_wrapper import single_calc_strength

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib import rc, font_manager
ticks_font = font_manager.FontProperties(family='serif', style='normal',
                                         size=24, weight='normal', stretch='normal')

# %%
# initiation
single_calc = single_calc_strength()

# %%
# available models 
single_calc.ssmodels_all
# Out:
# ['FCC_Varvenne-Curtin-2016',
#  'BCC_edge_Maresca-Curtin-2019',
#  'BCC_screw_Maresca-Curtin-2019',
#  'BCC_screw_Suzuki_RWASM-2020']

# %%
# prepare a dictonary of data
dict_NiCoFeCr = {"elements":{
                    "Co": {"structure":"fcc","Vn":11.12,"G":80,"nu":0.26,"b":2.544,"source":"Literature"},
                    "Ni": {"structure":"fcc","Vn":10.94,"G":80,"nu":0.26,"b":2.544,"source":"Literature"},
                    "Cr": {"structure":"fcc","Vn":12.27,"G":80,"nu":0.26,"b":2.544,"source":"Literature"},
                    "Fe": {"structure":"fcc","Vn":12.09,"G":80,"nu":0.26,"b":2.544,"source":"Literature"},
                    "Mn": {"structure":"fcc","Vn":12.60,"G":80,"nu":0.26,"b":2.544,"source":"Literature"}
                    }
                }

# %%
print('Example 1')
# specify model to use
single_calc.use_model('FCC_Varvenne-Curtin-2016')

# 3d TM CrFeCoNiMn
comp_example1 = {'Co':20,'Fe':20,'Ni':20,'Cr':20,'Mn':20}
# setup the system
single_calc.set_comp(comp_example1)
# specify the adjustable parameters for the model 
single_calc.set_adjustables(f1=0.35, 
                            f2=5.7, 
                            alpha=0.123)

# if not specified, adjustables have default values: 
# single_calc.set_adjustables()

# specify experimental conditions
temperature1 = np.linspace(293,673,20)
strain_r = 0.001
single_calc.set_temp(temperature1)
single_calc.set_strain_r(strain_r)
single_calc.exp_conditions()

# get data from user input
single_calc.grab_data(from_dict=dict_NiCoFeCr)
#print(single_calc.data_of_ssmodels)

# next make prediction
single_calc.calculate()
# if don't want to use model, remove it by
single_calc.remove_model('FCC_Varvenne-Curtin-2016')
single_calc.reorganize_data()
single_calc.pretty_calc_data
# Out:
# Example 1
# Currently using model(s): ['FCC_Varvenne-Curtin-2016']
# Alloy system: Co: 0.2 Fe: 0.2 Ni: 0.2 Cr: 0.2 Mn: 0.2
# Setting adjustable parameters of the model FCC_Varvenne-Curtin-2016.
# {'f1': 0.35, 'f2': 5.7, 'alpha': 0.123}
# Temperature: [293. 313. 333. 353. 373. 393. 413. 433. 453. 473. 493. 513. 533. 553.
#  573. 593. 613. 633. 653. 673.]
# Strain rate: 0.001
# grab elemental data for prediction.
# reading datafile None.
# Setting elemental data of the model FCC_Varvenne-Curtin-2016.
# Preparing Calculation -> FCC_Varvenne-Curtin-2016.
# Done Calculation. -> FCC_Varvenne-Curtin-2016.
# removing FCC_Varvenne-Curtin-2016 from the model set.
# Currently using model(s): [].
#       Co    Fe    Ni    Cr    Mn      T  strain_rate  tau_y structure  \
# 0   20.0  20.0  20.0  20.0  20.0  293.0        0.001  39.51       fcc
# 1   20.0  20.0  20.0  20.0  20.0  313.0        0.001  37.67       fcc
# 2   20.0  20.0  20.0  20.0  20.0  333.0        0.001  35.92       fcc
# 3   20.0  20.0  20.0  20.0  20.0  353.0        0.001  34.25       fcc
# 4   20.0  20.0  20.0  20.0  20.0  373.0        0.001  32.66       fcc
# 5   20.0  20.0  20.0  20.0  20.0  393.0        0.001  31.14       fcc
# 6   20.0  20.0  20.0  20.0  20.0  413.0        0.001  29.69       fcc
# 7   20.0  20.0  20.0  20.0  20.0  433.0        0.001  28.31       fcc
# 8   20.0  20.0  20.0  20.0  20.0  453.0        0.001  27.00       fcc
# 9   20.0  20.0  20.0  20.0  20.0  473.0        0.001  25.74       fcc
# 10  20.0  20.0  20.0  20.0  20.0  493.0        0.001  24.55       fcc
# 11  20.0  20.0  20.0  20.0  20.0  513.0        0.001  23.41       fcc
# 12  20.0  20.0  20.0  20.0  20.0  533.0        0.001  22.32       fcc
# 13  20.0  20.0  20.0  20.0  20.0  553.0        0.001  21.28       fcc
# 14  20.0  20.0  20.0  20.0  20.0  573.0        0.001  20.29       fcc
# 15  20.0  20.0  20.0  20.0  20.0  593.0        0.001  19.35       fcc
# 16  20.0  20.0  20.0  20.0  20.0  613.0        0.001  18.45       fcc
# 17  20.0  20.0  20.0  20.0  20.0  633.0        0.001  17.59       fcc
# 18  20.0  20.0  20.0  20.0  20.0  653.0        0.001  16.78       fcc
# 19  20.0  20.0  20.0  20.0  20.0  673.0        0.001  16.00       fcc
#
#                        model                              adjustables
# 0   FCC_Varvenne-Curtin-2016  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.123}
# 1   FCC_Varvenne-Curtin-2016  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.123}
# 2   FCC_Varvenne-Curtin-2016  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.123}
# 3   FCC_Varvenne-Curtin-2016  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.123}
# 4   FCC_Varvenne-Curtin-2016  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.123}
# 5   FCC_Varvenne-Curtin-2016  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.123}
# 6   FCC_Varvenne-Curtin-2016  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.123}
# 7   FCC_Varvenne-Curtin-2016  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.123}
# 8   FCC_Varvenne-Curtin-2016  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.123}
# 9   FCC_Varvenne-Curtin-2016  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.123}
# 10  FCC_Varvenne-Curtin-2016  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.123}
# 11  FCC_Varvenne-Curtin-2016  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.123}
# 12  FCC_Varvenne-Curtin-2016  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.123}
# 13  FCC_Varvenne-Curtin-2016  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.123}
# 14  FCC_Varvenne-Curtin-2016  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.123}
# 15  FCC_Varvenne-Curtin-2016  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.123}
# 16  FCC_Varvenne-Curtin-2016  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.123}
# 17  FCC_Varvenne-Curtin-2016  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.123}
# 18  FCC_Varvenne-Curtin-2016  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.123}
# 19  FCC_Varvenne-Curtin-2016  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.123}

# %%
paper_data_CrFeCoNiMn = [122.,79.,50.]
paper_T_CrFeCoNiMn = [293,473,673]

plt.draw()
f = plt.figure(figsize=(12,9))

(ax1) = f.subplots(1,1)
[i.set_linewidth(1.5) for i in ax1.spines.values()]

ax1.set_xlim(200.0,700)
ax1.set_ylim(0,160)
labels=[570,770,970,1170]

colors=np.array([[0,0,0],[30,136,229],[225,193,7],[212,27,93]])/256


mask = single_calc.calc_data_all['model']=='FCC_Varvenne-Curtin-2016'

ax1.plot(single_calc.calc_data_all[mask]['T'],single_calc.calc_data_all[mask]['tau_y']*3.067,
              'r-',
              label='predicted')
ax1.plot(paper_T_CrFeCoNiMn,paper_data_CrFeCoNiMn,'ro',markersize=12,label='reference')

ax1.tick_params(direction='in',axis='both',length=10,right=True)
for labelx1 in (ax1.get_xticklabels()):
    labelx1.set_fontproperties(ticks_font)
    
for labely1 in (ax1.get_yticklabels()):
    labely1.set_fontproperties(ticks_font)
    
ax1.set_xlabel('T (K)',fontproperties=ticks_font)
ax1.legend(fontsize=24,frameon=False)
ax1.set_ylabel(r'$\Delta \sigma_{ss}$ (MPa)',fontproperties=ticks_font)
# Out:
# Text(0, 0.5, '$\\Delta \\sigma_{ss}$ (MPa)')

# %%
dict_MoNbTaVW = {"elements":{
        "Mo": {"Vn":15.443,"G":92,"nu":0.433,"structure":'bcc'},
        "Nb": {"Vn":17.645,"G":92,"nu":0.433,"structure":'bcc'},
        "Ta": {"Vn":17.970,"G":92,"nu":0.433,"structure":'bcc'},
        "V": {"Vn":14.852,"G":92,"nu":0.433,"structure":'bcc'},
        "W": {"Vn":16.066,"G":92,"nu":0.433,"structure":'bcc'}}
        }

# %%
print('Example 2')
# specify model to use
single_calc.use_model('BCC_edge_Maresca-Curtin-2019')

# specify the adjustable parameters for the model 
single_calc.set_adjustables(alpha=0.0833)
# BCC refractory MoWNbZr
comp_example2 = {'Mo':20,'Nb':20,'Ta':20,'V':20, 'W':20}
# setup the system
single_calc.set_comp(comp_example2)
single_calc.grab_data(from_dict=dict_MoNbTaVW)
temperature2 = np.linspace(200,1900,20)
single_calc.set_temp(temperature2)
single_calc.calculate()

# if don't want to use model, remove it by
single_calc.remove_model('BCC_edge_Maresca-Curtin-2019')

single_calc.reorganize_data()
mask = single_calc.pretty_calc_data['model']=='BCC_edge_Maresca-Curtin-2019'
single_calc.pretty_calc_data[mask]
# Out:
# Example 2
# Currently using model(s): ['BCC_edge_Maresca-Curtin-2019']
# Setting adjustable parameters of the model BCC_edge_Maresca-Curtin-2019.
# {'f1': 0.7844, 'f2': 7.2993, 'alpha': 0.0833}
# Alloy system: Mo: 0.2 Nb: 0.2 Ta: 0.2 V: 0.2 W: 0.2
# grab elemental data for prediction.
# reading datafile None.
# Setting elemental data of the model BCC_edge_Maresca-Curtin-2019.
# Preparing Calculation -> BCC_edge_Maresca-Curtin-2019.
# Done Calculation. -> BCC_edge_Maresca-Curtin-2019.
# removing BCC_edge_Maresca-Curtin-2019 from the model set.
# Currently using model(s): [].
#     Co  Fe  Ni  Cr  Mn    Mo    Nb    Ta     V     W            T  \
# 20 NaN NaN NaN NaN NaN  20.0  20.0  20.0  20.0  20.0   200.000000
# 21 NaN NaN NaN NaN NaN  20.0  20.0  20.0  20.0  20.0   289.473684
# 22 NaN NaN NaN NaN NaN  20.0  20.0  20.0  20.0  20.0   378.947368
# 23 NaN NaN NaN NaN NaN  20.0  20.0  20.0  20.0  20.0   468.421053
# 24 NaN NaN NaN NaN NaN  20.0  20.0  20.0  20.0  20.0   557.894737
# 25 NaN NaN NaN NaN NaN  20.0  20.0  20.0  20.0  20.0   647.368421
# 26 NaN NaN NaN NaN NaN  20.0  20.0  20.0  20.0  20.0   736.842105
# 27 NaN NaN NaN NaN NaN  20.0  20.0  20.0  20.0  20.0   826.315789
# 28 NaN NaN NaN NaN NaN  20.0  20.0  20.0  20.0  20.0   915.789474
# 29 NaN NaN NaN NaN NaN  20.0  20.0  20.0  20.0  20.0  1005.263158
# 30 NaN NaN NaN NaN NaN  20.0  20.0  20.0  20.0  20.0  1094.736842
# 31 NaN NaN NaN NaN NaN  20.0  20.0  20.0  20.0  20.0  1184.210526
# 32 NaN NaN NaN NaN NaN  20.0  20.0  20.0  20.0  20.0  1273.684211
# 33 NaN NaN NaN NaN NaN  20.0  20.0  20.0  20.0  20.0  1363.157895
# 34 NaN NaN NaN NaN NaN  20.0  20.0  20.0  20.0  20.0  1452.631579
# 35 NaN NaN NaN NaN NaN  20.0  20.0  20.0  20.0  20.0  1542.105263
# 36 NaN NaN NaN NaN NaN  20.0  20.0  20.0  20.0  20.0  1631.578947
# 37 NaN NaN NaN NaN NaN  20.0  20.0  20.0  20.0  20.0  1721.052632
# 38 NaN NaN NaN NaN NaN  20.0  20.0  20.0  20.0  20.0  1810.526316
# 39 NaN NaN NaN NaN NaN  20.0  20.0  20.0  20.0  20.0  1900.000000
#
#     strain_rate   tau_y structure                         model  \
# 20        0.001  508.89       bcc  BCC_edge_Maresca-Curtin-2019
# 21        0.001  471.69       bcc  BCC_edge_Maresca-Curtin-2019
# 22        0.001  438.20       bcc  BCC_edge_Maresca-Curtin-2019
# 23        0.001  407.26       bcc  BCC_edge_Maresca-Curtin-2019
# 24        0.001  378.25       bcc  BCC_edge_Maresca-Curtin-2019
# 25        0.001  350.76       bcc  BCC_edge_Maresca-Curtin-2019
# 26        0.001  324.51       bcc  BCC_edge_Maresca-Curtin-2019
# 27        0.001  315.92       bcc  BCC_edge_Maresca-Curtin-2019
# 28        0.001  292.57       bcc  BCC_edge_Maresca-Curtin-2019
# 29        0.001  270.95       bcc  BCC_edge_Maresca-Curtin-2019
# 30        0.001  250.93       bcc  BCC_edge_Maresca-Curtin-2019
# 31        0.001  232.38       bcc  BCC_edge_Maresca-Curtin-2019
# 32        0.001  215.21       bcc  BCC_edge_Maresca-Curtin-2019
# 33        0.001  199.30       bcc  BCC_edge_Maresca-Curtin-2019
# 34        0.001  184.57       bcc  BCC_edge_Maresca-Curtin-2019
# 35        0.001  170.93       bcc  BCC_edge_Maresca-Curtin-2019
# 36        0.001  158.30       bcc  BCC_edge_Maresca-Curtin-2019
# 37        0.001  146.60       bcc  BCC_edge_Maresca-Curtin-2019
# 38        0.001  135.77       bcc  BCC_edge_Maresca-Curtin-2019
# 39        0.001  125.73       bcc  BCC_edge_Maresca-Curtin-2019
#
#                                       adjustables
# 20  {'f1': 0.7844, 'f2': 7.2993, 'alpha': 0.0833}
# 21  {'f1': 0.7844, 'f2': 7.2993, 'alpha': 0.0833}
# 22  {'f1': 0.7844, 'f2': 7.2993, 'alpha': 0.0833}
# 23  {'f1': 0.7844, 'f2': 7.2993, 'alpha': 0.0833}
# 24  {'f1': 0.7844, 'f2': 7.2993, 'alpha': 0.0833}
# 25  {'f1': 0.7844, 'f2': 7.2993, 'alpha': 0.0833}
# 26  {'f1': 0.7844, 'f2': 7.2993, 'alpha': 0.0833}
# 27  {'f1': 0.7844, 'f2': 7.2993, 'alpha': 0.0833}
# 28  {'f1': 0.7844, 'f2': 7.2993, 'alpha': 0.0833}
# 29  {'f1': 0.7844, 'f2': 7.2993, 'alpha': 0.0833}
# 30  {'f1': 0.7844, 'f2': 7.2993, 'alpha': 0.0833}
# 31  {'f1': 0.7844, 'f2': 7.2993, 'alpha': 0.0833}
# 32  {'f1': 0.7844, 'f2': 7.2993, 'alpha': 0.0833}
# 33  {'f1': 0.7844, 'f2': 7.2993, 'alpha': 0.0833}
# 34  {'f1': 0.7844, 'f2': 7.2993, 'alpha': 0.0833}
# 35  {'f1': 0.7844, 'f2': 7.2993, 'alpha': 0.0833}
# 36  {'f1': 0.7844, 'f2': 7.2993, 'alpha': 0.0833}
# 37  {'f1': 0.7844, 'f2': 7.2993, 'alpha': 0.0833}
# 38  {'f1': 0.7844, 'f2': 7.2993, 'alpha': 0.0833}
# 39  {'f1': 0.7844, 'f2': 7.2993, 'alpha': 0.0833}

# %%
paper_data_MoNbTaVW = pd.read_csv('./MoNbTaVW_paper_extracted.csv',sep='\s+')

plt.draw()
f = plt.figure(figsize=(12,9))

(ax1) = f.subplots(1,1)
[i.set_linewidth(1.5) for i in ax1.spines.values()]

ax1.set_xlim(0,1800)
ax1.set_ylim(0,1600)
labels=[570,770,970,1170]

colors=np.array([[0,0,0],[30,136,229],[225,193,7],[212,27,93]])/256


mask = single_calc.calc_data_all['model']=='BCC_edge_Maresca-Curtin-2019'

ax1.plot(single_calc.calc_data_all[mask]['T'],single_calc.calc_data_all[mask]['tau_y']*3.067,'b-',label='predicted')
ax1.plot(paper_data_MoNbTaVW['x'],paper_data_MoNbTaVW['y'],'bs',markersize=12,label='reference')

ax1.tick_params(direction='in',axis='both',length=10,right=True)
for labelx1 in (ax1.get_xticklabels()):
    labelx1.set_fontproperties(ticks_font)
    
for labely1 in (ax1.get_yticklabels()):
    labely1.set_fontproperties(ticks_font)
    
ax1.set_xlabel('T (K)',fontproperties=ticks_font)
ax1.legend(fontsize=24,frameon=False)
ax1.set_ylabel(r'$\Delta \sigma_{ss}$ (MPa)',fontproperties=ticks_font)
# Out:
# Text(0, 0.5, '$\\Delta \\sigma_{ss}$ (MPa)')

# %%
dict_NbW = {"elements":{
    "Nb95Mo5":{"structure":"bcc", "a":3.289,"Delta_E_p":0.0488,"E_k":0.6342,"E_f_v":2.989,"E_f_si":5.361,"Delta_V_p":0.02,"source":"Literature"}
            }}

# %%
print('Example 3')
# specify model to use

single_calc.use_model('BCC_screw_Maresca-Curtin-2019')

# specify the adjustable parameters for the model 
single_calc.set_adjustables(kink_width=10, 
                            Delta_V_p_scaler=1, 
                            Delta_E_p_scaler=1)

# BCC refractory MoWNbZr
comp_example3 = {'Nb95Mo5':100}
# setup the system
single_calc.set_comp(comp_example3)
single_calc.grab_data(from_dict=dict_NbW)
temperature3 = np.linspace(0,500,100)
single_calc.set_temp(temperature3)


single_calc.calculate()
# if don't want to use model, remove it by
single_calc.remove_model('BCC_screw_Maresca-Curtin-2019')


single_calc.reorganize_data()
mask = single_calc.pretty_calc_data['model']=='BCC_screw_Maresca-Curtin-2019'
single_calc.pretty_calc_data[mask]
# Out:
# Example 3
# Currently using model(s): ['BCC_screw_Maresca-Curtin-2019']
# Setting adjustable parameters of the model BCC_screw_Maresca-Curtin-2019.
# {'kink_width': 10.0, 'Delta_V_p_scaler': 1.0, 'Delta_E_p_scaler': 1.0}
# Alloy system: Nb95Mo5: 1.0
# grab elemental data for prediction.
# reading datafile None.
# Setting elemental data of the model BCC_screw_Maresca-Curtin-2019.
# Preparing Calculation -> BCC_screw_Maresca-Curtin-2019.
# Done Calculation. -> BCC_screw_Maresca-Curtin-2019.
# removing BCC_screw_Maresca-Curtin-2019 from the model set.
# Currently using model(s): [].
#      Co  Fe  Ni  Cr  Mn  Mo  Nb  Ta   V   W  Nb95Mo5           T  strain_rate  \
# 40  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN    100.0    0.000000        0.001
# 41  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN    100.0    5.050505        0.001
# 42  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN    100.0   10.101010        0.001
# 43  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN    100.0   15.151515        0.001
# 44  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN    100.0   20.202020        0.001
# ..   ..  ..  ..  ..  ..  ..  ..  ..  ..  ..      ...         ...          ...
# 135 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN    100.0  479.797980        0.001
# 136 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN    100.0  484.848485        0.001
# 137 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN    100.0  489.898990        0.001
# 138 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN    100.0  494.949495        0.001
# 139 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN    100.0  500.000000        0.001
#
#       tau_y structure                          model  \
# 40   516.31       bcc  BCC_screw_Maresca-Curtin-2019
# 41   511.81       bcc  BCC_screw_Maresca-Curtin-2019
# 42   509.16       bcc  BCC_screw_Maresca-Curtin-2019
# 43   506.95       bcc  BCC_screw_Maresca-Curtin-2019
# 44   473.08       bcc  BCC_screw_Maresca-Curtin-2019
# ..      ...       ...                            ...
# 135   69.13       bcc  BCC_screw_Maresca-Curtin-2019
# 136   68.67       bcc  BCC_screw_Maresca-Curtin-2019
# 137   68.22       bcc  BCC_screw_Maresca-Curtin-2019
# 138   67.78       bcc  BCC_screw_Maresca-Curtin-2019
# 139   67.36       bcc  BCC_screw_Maresca-Curtin-2019
#
#                                            adjustables
# 40   {'kink_width': 10.0, 'Delta_V_p_scaler': 1.0, ...
# 41   {'kink_width': 10.0, 'Delta_V_p_scaler': 1.0, ...
# 42   {'kink_width': 10.0, 'Delta_V_p_scaler': 1.0, ...
# 43   {'kink_width': 10.0, 'Delta_V_p_scaler': 1.0, ...
# 44   {'kink_width': 10.0, 'Delta_V_p_scaler': 1.0, ...
# ..                                                 ...
# 135  {'kink_width': 10.0, 'Delta_V_p_scaler': 1.0, ...
# 136  {'kink_width': 10.0, 'Delta_V_p_scaler': 1.0, ...
# 137  {'kink_width': 10.0, 'Delta_V_p_scaler': 1.0, ...
# 138  {'kink_width': 10.0, 'Delta_V_p_scaler': 1.0, ...
# 139  {'kink_width': 10.0, 'Delta_V_p_scaler': 1.0, ...
#
# [100 rows x 17 columns]

# %%
paper_data_NbW = pd.read_csv('./Nb95Mo5_paper_extracted.csv',sep='\s+')


plt.draw()
f = plt.figure(figsize=(12,9))

(ax1) = f.subplots(1,1)
[i.set_linewidth(1.5) for i in ax1.spines.values()]

ax1.set_xlim(0,500)
ax1.set_ylim(0,600)
labels=[570,770,970,1170]

colors=np.array([[0,0,0],[30,136,229],[225,193,7],[212,27,93]])/256


mask = single_calc.calc_data_all['model']=='BCC_screw_Maresca-Curtin-2019'

ax1.plot(single_calc.calc_data_all[mask]['T'],single_calc.calc_data_all[mask]['tau_y'],'g-',label='predicted')
ax1.plot(paper_data_NbW['x'],paper_data_NbW['y'],'g*',markersize=12,label='reference')

ax1.tick_params(direction='in',axis='both',length=10,right=True)
for labelx1 in (ax1.get_xticklabels()):
    labelx1.set_fontproperties(ticks_font)
    
for labely1 in (ax1.get_yticklabels()):
    labely1.set_fontproperties(ticks_font)
    
ax1.set_xlabel('T (K)',fontproperties=ticks_font)
ax1.legend(fontsize=24,frameon=False)
ax1.set_ylabel(r'$\tau_y$ (MPa)',fontproperties=ticks_font)
# Out:
# Text(0, 0.5, '$\\tau_y$ (MPa)')

# %%
dict_TiNbZr = {    "elements":{
        "Nb": {"structure":'bcc',"a":3.30,"G":38,"nu":0.40,"E_w_i":0.054 ,"E_f_v":2.99,"E_f_si":5.25},
        "Ti": {"structure":'bcc',"a":3.31,"G":44,"nu":0.32,"E_w_i":-0.028,"E_f_v":2.22,"E_f_si":2.4},
        "Zr": {"structure":'bcc',"a":3.58,"G":33,"nu":0.34,"E_w_i":-0.053,"E_f_v":1.80,"E_f_si":3.5},
        "IT": {"structure":'bcc',"a":3.39,"G":33,"nu":0.34,"E_w_i":0.5,"E_f_v":3,"E_f_si":5} # IT 
    }}

# %%
# Now, select another model to use: 
print('Example 4')
single_calc.use_model('BCC_screw_Suzuki_RWASM-2020')

# setup another system: TiNbZr
comp_example4 = {'Nb':32,'Ti':33,'Zr':34,'IT':0.54}
single_calc.set_comp(comp_example4)



# specify the adjustable parameters for the model 
single_calc.set_adjustables(kink_width=10, 
                             tau_i_exponent = 1, 
                             dislocation_density= 4e13, 
                             trial_kappa={'min': 1, 'max': 4, 'inc': 0.5}, 
                             trial_tau_k = 5)

single_calc.set_comp(comp_example4)
single_calc.grab_data(from_dict=dict_TiNbZr)
temperature4 = np.linspace(293,1073,11)
single_calc.set_temp(temperature4)

single_calc.calculate()

single_calc.remove_model('BCC_screw_Suzuki_RWASM-2020')

single_calc.reorganize_data()
mask = single_calc.pretty_calc_data['model']=='BCC_screw_Suzuki_RWASM-2020'
single_calc.pretty_calc_data[mask]
# Out:
# Example 4
# Currently using model(s): ['BCC_screw_Suzuki_RWASM-2020']
# Your composition does not sum to 1.0. Perform normalization.
# Alloy system: Nb: 0.32 Ti: 0.33 Zr: 0.34 IT: 0.01
# Setting adjustable parameters of the model BCC_screw_Suzuki_RWASM-2020.
# {'kink_width': 10.0, 'tau_i_exponent': 1.0, 'dislocation_density': 40000000000000.0, 'trial_kappa': {'min': 1.0, 'max': 4.0, 'inc': 0.5}, 'trial_tau_k': 5.0}
# Alloy system: Nb: 0.32 Ti: 0.33 Zr: 0.34 IT: 0.01
# grab elemental data for prediction.
# reading datafile None.
# Setting elemental data of the model BCC_screw_Suzuki_RWASM-2020.
# Preparing Calculation -> BCC_screw_Suzuki_RWASM-2020.
# no Tl (liquidus temperature) supplied, cannot predict high-temperature jog-dragging mode.
# Done Calculation. -> BCC_screw_Suzuki_RWASM-2020.
# removing BCC_screw_Suzuki_RWASM-2020 from the model set.
# Currently using model(s): [].
#      Co  Fe  Ni  Cr  Mn  Mo        Nb  Ta   V   W  ...         Zr        IT  \
# 140 NaN NaN NaN NaN NaN NaN  32.14788 NaN NaN NaN  ...  34.157123  0.542495
# 141 NaN NaN NaN NaN NaN NaN  32.14788 NaN NaN NaN  ...  34.157123  0.542495
# 142 NaN NaN NaN NaN NaN NaN  32.14788 NaN NaN NaN  ...  34.157123  0.542495
# 143 NaN NaN NaN NaN NaN NaN  32.14788 NaN NaN NaN  ...  34.157123  0.542495
# 144 NaN NaN NaN NaN NaN NaN  32.14788 NaN NaN NaN  ...  34.157123  0.542495
# 145 NaN NaN NaN NaN NaN NaN  32.14788 NaN NaN NaN  ...  34.157123  0.542495
# 146 NaN NaN NaN NaN NaN NaN  32.14788 NaN NaN NaN  ...  34.157123  0.542495
# 147 NaN NaN NaN NaN NaN NaN  32.14788 NaN NaN NaN  ...  34.157123  0.542495
# 148 NaN NaN NaN NaN NaN NaN  32.14788 NaN NaN NaN  ...  34.157123  0.542495
# 149 NaN NaN NaN NaN NaN NaN  32.14788 NaN NaN NaN  ...  34.157123  0.542495
# 150 NaN NaN NaN NaN NaN NaN  32.14788 NaN NaN NaN  ...  34.157123  0.542495
#
#      T_liquidus  jog_activated       T strain_rate   tau_y  structure  \
# 140         NaN          False   293.0       0.001  409.98        bcc
# 141         NaN          False   371.0       0.001  346.94        bcc
# 142         NaN          False   449.0       0.001  302.68        bcc
# 143         NaN          False   527.0       0.001  269.66        bcc
# 144         NaN          False   605.0       0.001  243.90        bcc
# 145         NaN          False   683.0       0.001  223.12        bcc
# 146         NaN          False   761.0       0.001  205.97        bcc
# 147         NaN          False   839.0       0.001  191.54        bcc
# 148         NaN          False   917.0       0.001  179.21        bcc
# 149         NaN          False   995.0       0.001  168.53        bcc
# 150         NaN          False  1073.0       0.001  159.17        bcc
#
#                            model  \
# 140  BCC_screw_Suzuki_RWASM-2020
# 141  BCC_screw_Suzuki_RWASM-2020
# 142  BCC_screw_Suzuki_RWASM-2020
# 143  BCC_screw_Suzuki_RWASM-2020
# 144  BCC_screw_Suzuki_RWASM-2020
# 145  BCC_screw_Suzuki_RWASM-2020
# 146  BCC_screw_Suzuki_RWASM-2020
# 147  BCC_screw_Suzuki_RWASM-2020
# 148  BCC_screw_Suzuki_RWASM-2020
# 149  BCC_screw_Suzuki_RWASM-2020
# 150  BCC_screw_Suzuki_RWASM-2020
#
#                                            adjustables
# 140  {'kink_width': 10.0, 'tau_i_exponent': 1.0, 'd...
# 141  {'kink_width': 10.0, 'tau_i_exponent': 1.0, 'd...
# 142  {'kink_width': 10.0, 'tau_i_exponent': 1.0, 'd...
# 143  {'kink_width': 10.0, 'tau_i_exponent': 1.0, 'd...
# 144  {'kink_width': 10.0, 'tau_i_exponent': 1.0, 'd...
# 145  {'kink_width': 10.0, 'tau_i_exponent': 1.0, 'd...
# 146  {'kink_width': 10.0, 'tau_i_exponent': 1.0, 'd...
# 147  {'kink_width': 10.0, 'tau_i_exponent': 1.0, 'd...
# 148  {'kink_width': 10.0, 'tau_i_exponent': 1.0, 'd...
# 149  {'kink_width': 10.0, 'tau_i_exponent': 1.0, 'd...
# 150  {'kink_width': 10.0, 'tau_i_exponent': 1.0, 'd...
#
# [11 rows x 22 columns]

# %%
paper_data_TiNbZr = pd.read_csv('./TiINbZr_paper_extracted.csv',sep='\s+')


plt.plot(single_calc.calc_data_all[mask]['T'],single_calc.calc_data_all[mask]['tau_y']*2.76,'r-',label='predicted tau_y')
plt.plot(paper_data_TiNbZr['x'],paper_data_TiNbZr['y'],'ro',label='paper data')
plt.ylim(0,1200)
#plt.xlim(250,700)
plt.legend()

# %%
# now to calculate the 1273 K jog mode
T_liquidus_TiNbZr = 1961.

# %%
single_calc.use_model('BCC_screw_Suzuki_RWASM-2020')

# setup another system: TiNbZr
comp_example4 = {'Nb':32,'Ti':33,'Zr':34,'IT':0.54}
single_calc.set_comp(comp_example4)
single_calc.grab_data(from_dict=dict_TiNbZr)
# specify the adjustable parameters for the model 
single_calc.set_adjustables(kink_width=10, 
                             tau_i_exponent = 1, 
                             dislocation_density= 4e13, 
                             trial_kappa={'min': 1, 'max': 4, 'inc': 0.5}, 
                             trial_tau_k = 5)
# set liquidus temperature
single_calc.set_T_l(T_liquidus_TiNbZr)

single_calc.set_temp(1273)
# set strain rate 
# paper used 0.001 and 0.0001 for 1273 K 
# so for the resulting tau_y, take the average.
for strain_rate in [0.001,0.0001]:
    single_calc.set_strain_r(strain_rate)
    single_calc.calculate()



single_calc.remove_model('BCC_screw_Suzuki_RWASM-2020')

single_calc.reorganize_data()
mask = single_calc.pretty_calc_data['model']=='BCC_screw_Suzuki_RWASM-2020'
single_calc.pretty_calc_data[mask]
# Out:
# Currently using model(s): ['BCC_screw_Suzuki_RWASM-2020']
# Your composition does not sum to 1.0. Perform normalization.
# Alloy system: Nb: 0.32 Ti: 0.33 Zr: 0.34 IT: 0.01
# grab elemental data for prediction.
# reading datafile None.
# Setting elemental data of the model BCC_screw_Suzuki_RWASM-2020.
# Setting adjustable parameters of the model BCC_screw_Suzuki_RWASM-2020.
# {'kink_width': 10.0, 'tau_i_exponent': 1.0, 'dislocation_density': 40000000000000.0, 'trial_kappa': {'min': 1.0, 'max': 4.0, 'inc': 0.5}, 'trial_tau_k': 5.0}
# Preparing Calculation -> BCC_screw_Suzuki_RWASM-2020.
# Done Calculation. -> BCC_screw_Suzuki_RWASM-2020.
# Preparing Calculation -> BCC_screw_Suzuki_RWASM-2020.
# Done Calculation. -> BCC_screw_Suzuki_RWASM-2020.
# removing BCC_screw_Suzuki_RWASM-2020 from the model set.
# Currently using model(s): [].
#      Co  Fe  Ni  Cr  Mn  Mo        Nb  Ta   V   W  ...         Zr        IT  \
# 140 NaN NaN NaN NaN NaN NaN  32.14788 NaN NaN NaN  ...  34.157123  0.542495
# 141 NaN NaN NaN NaN NaN NaN  32.14788 NaN NaN NaN  ...  34.157123  0.542495
# 142 NaN NaN NaN NaN NaN NaN  32.14788 NaN NaN NaN  ...  34.157123  0.542495
# 143 NaN NaN NaN NaN NaN NaN  32.14788 NaN NaN NaN  ...  34.157123  0.542495
# 144 NaN NaN NaN NaN NaN NaN  32.14788 NaN NaN NaN  ...  34.157123  0.542495
# 145 NaN NaN NaN NaN NaN NaN  32.14788 NaN NaN NaN  ...  34.157123  0.542495
# 146 NaN NaN NaN NaN NaN NaN  32.14788 NaN NaN NaN  ...  34.157123  0.542495
# 147 NaN NaN NaN NaN NaN NaN  32.14788 NaN NaN NaN  ...  34.157123  0.542495
# 148 NaN NaN NaN NaN NaN NaN  32.14788 NaN NaN NaN  ...  34.157123  0.542495
# 149 NaN NaN NaN NaN NaN NaN  32.14788 NaN NaN NaN  ...  34.157123  0.542495
# 150 NaN NaN NaN NaN NaN NaN  32.14788 NaN NaN NaN  ...  34.157123  0.542495
# 152 NaN NaN NaN NaN NaN NaN  32.14788 NaN NaN NaN  ...  34.157123  0.542495
# 153 NaN NaN NaN NaN NaN NaN  32.14788 NaN NaN NaN  ...  34.157123  0.542495
#
#      T_liquidus  jog_activated       T strain_rate   tau_y  structure  \
# 140         NaN          False   293.0      0.0010  409.98        bcc
# 141         NaN          False   371.0      0.0010  346.94        bcc
# 142         NaN          False   449.0      0.0010  302.68        bcc
# 143         NaN          False   527.0      0.0010  269.66        bcc
# 144         NaN          False   605.0      0.0010  243.90        bcc
# 145         NaN          False   683.0      0.0010  223.12        bcc
# 146         NaN          False   761.0      0.0010  205.97        bcc
# 147         NaN          False   839.0      0.0010  191.54        bcc
# 148         NaN          False   917.0      0.0010  179.21        bcc
# 149         NaN          False   995.0      0.0010  168.53        bcc
# 150         NaN          False  1073.0      0.0010  159.17        bcc
# 152      1961.0           True  1273.0      0.0010   76.57        bcc
# 153      1961.0           True  1273.0      0.0001   45.27        bcc
#
#                            model  \
# 140  BCC_screw_Suzuki_RWASM-2020
# 141  BCC_screw_Suzuki_RWASM-2020
# 142  BCC_screw_Suzuki_RWASM-2020
# 143  BCC_screw_Suzuki_RWASM-2020
# 144  BCC_screw_Suzuki_RWASM-2020
# 145  BCC_screw_Suzuki_RWASM-2020
# 146  BCC_screw_Suzuki_RWASM-2020
# 147  BCC_screw_Suzuki_RWASM-2020
# 148  BCC_screw_Suzuki_RWASM-2020
# 149  BCC_screw_Suzuki_RWASM-2020
# 150  BCC_screw_Suzuki_RWASM-2020
# 152  BCC_screw_Suzuki_RWASM-2020
# 153  BCC_screw_Suzuki_RWASM-2020
#
#                                            adjustables
# 140  {'kink_width': 10.0, 'tau_i_exponent': 1.0, 'd...
# 141  {'kink_width': 10.0, 'tau_i_exponent': 1.0, 'd...
# 142  {'kink_width': 10.0, 'tau_i_exponent': 1.0, 'd...
# 143  {'kink_width': 10.0, 'tau_i_exponent': 1.0, 'd...
# 144  {'kink_width': 10.0, 'tau_i_exponent': 1.0, 'd...
# 145  {'kink_width': 10.0, 'tau_i_exponent': 1.0, 'd...
# 146  {'kink_width': 10.0, 'tau_i_exponent': 1.0, 'd...
# 147  {'kink_width': 10.0, 'tau_i_exponent': 1.0, 'd...
# 148  {'kink_width': 10.0, 'tau_i_exponent': 1.0, 'd...
# 149  {'kink_width': 10.0, 'tau_i_exponent': 1.0, 'd...
# 150  {'kink_width': 10.0, 'tau_i_exponent': 1.0, 'd...
# 152  {'kink_width': 10.0, 'tau_i_exponent': 1.0, 'd...
# 153  {'kink_width': 10.0, 'tau_i_exponent': 1.0, 'd...
#
# [13 rows x 22 columns]

# %%
paper_data_TiNbZr = pd.read_csv('./TiINbZr_paper_extracted.csv',sep='\s+')



plt.draw()
f = plt.figure(figsize=(12,9))

(ax1) = f.subplots(1,1)
[i.set_linewidth(1.5) for i in ax1.spines.values()]

ax1.set_xlim(0,1400)
ax1.set_ylim(0,1200)
labels=[570,770,970,1170]

colors=np.array([[0,0,0],[30,136,229],[225,193,7],[212,27,93]])/256


mask = single_calc.calc_data_all['model']=='BCC_screw_Suzuki_RWASM-2020'

ax1.plot(single_calc.calc_data_all[mask]['T'],single_calc.calc_data_all[mask]['tau_y']*2.76,'ks-',
         markersize=12,label='predicted')
ax1.plot(paper_data_TiNbZr['x'],paper_data_TiNbZr['y'],'rd',
                  markersize=12,label='reference')

ax1.tick_params(direction='in',axis='both',length=10,right=True)
for labelx1 in (ax1.get_xticklabels()):
    labelx1.set_fontproperties(ticks_font)
    
for labely1 in (ax1.get_yticklabels()):
    labely1.set_fontproperties(ticks_font)
    
ax1.set_xlabel('T (K)',fontproperties=ticks_font)
ax1.legend(fontsize=24,frameon=False)
ax1.set_ylabel(r'$\tau_y$ (MPa)',fontproperties=ticks_font)
# Out:
# Text(0, 0.5, '$\\tau_y$ (MPa)')
