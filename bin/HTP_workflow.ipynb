# %%
from sspredict.make_prediction.single_calc_wrapper import single_calc_strength

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib import rc, font_manager
ticks_font = font_manager.FontProperties(family='serif', style='normal',
                                         size=24, weight='normal', stretch='normal')

# %%
# initiation
single_calc = single_calc_strength()

# %%
# available models 
single_calc.ssmodels_all
# Out:
# ['FCC_Varvenne-Curtin-2016',
#  'BCC_edge_Maresca-Curtin-2019',
#  'BCC_screw_Maresca-Curtin-2019',
#  'BCC_screw_Suzuki_RWASM-2020']

# %%
# prepare a json file with data
filein='../examples/sample_elements_data.json'

# %%
print('Example 1')
# specify model to use
single_calc.use_model('FCC_Varvenne-Curtin-2016')

# 3d TM CrFeCoNi
comp_example1 = {'Co':25,'Fe':25,'Ni':25,'Mn':25}
# setup the system
single_calc.set_comp(comp_example1)
# specify the adjustable parameters for the model 
single_calc.set_adjustables(f1=0.35, 
                            f2=5.7, 
                            alpha=1/16)

# if not specified, adjustables have default values: 
# single_calc.set_adjustables()

# specify experimental conditions
temperature = np.arange(0,600,100)
strain_r = 0.001
single_calc.set_temp(temperature)
single_calc.set_strain_r(strain_r)
single_calc.exp_conditions()

# get data from user input
single_calc.grab_data(filein)
#print(single_calc.data_of_ssmodels)

# next make prediction
single_calc.calculate()
# if don't want to use model, remove it by
single_calc.remove_model('FCC_Varvenne-Curtin-2016')
single_calc.reorganize_data()
single_calc.pretty_calc_data
# Out:
# Example 1
# Currently using model(s): ['FCC_Varvenne-Curtin-2016']
# Alloy system: Co: 0.25 Fe: 0.25 Ni: 0.25 Mn: 0.25
# Setting adjustable parameters of the model FCC_Varvenne-Curtin-2016.
# {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# Temperature: [  0 100 200 300 400 500]
# Strain rate: 0.001
# grab elemental data for prediction.
# reading datafile ../examples/sample_elements_data.json.
# Setting elemental data of the model FCC_Varvenne-Curtin-2016.
# Preparing Calculation -> FCC_Varvenne-Curtin-2016.
# Done Calculation. -> FCC_Varvenne-Curtin-2016.
# removing FCC_Varvenne-Curtin-2016 from the model set.
# Currently using model(s): [].
#      Co    Fe    Ni    Mn      T  strain_rate   tau_y structure  \
# 0  25.0  25.0  25.0  25.0    0.0        0.001  126.10       fcc
# 1  25.0  25.0  25.0  25.0  100.0        0.001   91.42       fcc
# 2  25.0  25.0  25.0  25.0  200.0        0.001   71.06       fcc
# 3  25.0  25.0  25.0  25.0  300.0        0.001   57.43       fcc
# 4  25.0  25.0  25.0  25.0  400.0        0.001   44.18       fcc
# 5  25.0  25.0  25.0  25.0  500.0        0.001   33.99       fcc
#
#                       model                               adjustables
# 0  FCC_Varvenne-Curtin-2016  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 1  FCC_Varvenne-Curtin-2016  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 2  FCC_Varvenne-Curtin-2016  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 3  FCC_Varvenne-Curtin-2016  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 4  FCC_Varvenne-Curtin-2016  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 5  FCC_Varvenne-Curtin-2016  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}

# %%
print('Example 2')
# specify model to use
single_calc.use_model('BCC_edge_Maresca-Curtin-2019')

# specify the adjustable parameters for the model 
single_calc.set_adjustables(f1=0.35, 
                            f2=5.7, 
                            alpha=1/12)
# BCC refractory MoWNbZr
comp_example2 = {'Mo':25,'W':25,'Nb':25,'Zr':25}
# setup the system
single_calc.set_comp(comp_example2)
single_calc.grab_data(filein)

single_calc.calculate()

# if don't want to use model, remove it by
single_calc.remove_model('BCC_edge_Maresca-Curtin-2019')

single_calc.reorganize_data()
single_calc.pretty_calc_data
# Out:
# Example 2
# Currently using model(s): ['BCC_edge_Maresca-Curtin-2019']
# Setting adjustable parameters of the model BCC_edge_Maresca-Curtin-2019.
# {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333333333}
# Alloy system: Mo: 0.25 W: 0.25 Nb: 0.25 Zr: 0.25
# grab elemental data for prediction.
# reading datafile ../examples/sample_elements_data.json.
# Setting elemental data of the model BCC_edge_Maresca-Curtin-2019.
# Preparing Calculation -> BCC_edge_Maresca-Curtin-2019.
# Done Calculation. -> BCC_edge_Maresca-Curtin-2019.
# removing BCC_edge_Maresca-Curtin-2019 from the model set.
# Currently using model(s): [].
#       Co    Fe    Ni    Mn    Mo     W    Nb    Zr      T  strain_rate  \
# 0   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN    0.0        0.001
# 1   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN  100.0        0.001
# 2   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN  200.0        0.001
# 3   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN  300.0        0.001
# 4   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN  400.0        0.001
# 5   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN  500.0        0.001
# 6    NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0    0.0        0.001
# 7    NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0  100.0        0.001
# 8    NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0  200.0        0.001
# 9    NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0  300.0        0.001
# 10   NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0  400.0        0.001
# 11   NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0  500.0        0.001
#
#      tau_y structure                         model  \
# 0   126.10       fcc      FCC_Varvenne-Curtin-2016
# 1    91.42       fcc      FCC_Varvenne-Curtin-2016
# 2    71.06       fcc      FCC_Varvenne-Curtin-2016
# 3    57.43       fcc      FCC_Varvenne-Curtin-2016
# 4    44.18       fcc      FCC_Varvenne-Curtin-2016
# 5    33.99       fcc      FCC_Varvenne-Curtin-2016
# 6   569.02       bcc  BCC_edge_Maresca-Curtin-2019
# 7   501.84       bcc  BCC_edge_Maresca-Curtin-2019
# 8   462.37       bcc  BCC_edge_Maresca-Curtin-2019
# 9   429.27       bcc  BCC_edge_Maresca-Curtin-2019
# 10  399.73       bcc  BCC_edge_Maresca-Curtin-2019
# 11  372.57       bcc  BCC_edge_Maresca-Curtin-2019
#
#                                           adjustables
# 0            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 1            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 2            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 3            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 4            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 5            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 6   {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 7   {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 8   {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 9   {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 10  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 11  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...

# %%
print('Example 3')
# specify model to use

single_calc.use_model('BCC_screw_Maresca-Curtin-2019')

# specify the adjustable parameters for the model 
single_calc.set_adjustables(kink_width=20, 
                            Delta_V_p_scaler=1, 
                            Delta_E_p_scaler=1)

# BCC refractory MoWNbZr
comp_example3 = {'Nb':34,"W":33,"Mo":33}
# setup the system
single_calc.set_comp(comp_example3)
single_calc.grab_data(filein)

print(single_calc.data_of_ssmodels['BCC_screw_Maresca-Curtin-2019'])
single_calc.calculate()
# if don't want to use model, remove it by
single_calc.remove_model('BCC_screw_Maresca-Curtin-2019')

single_calc.reorganize_data()
single_calc.pretty_calc_data
# Out:
# Example 3
# Currently using model(s): ['BCC_screw_Maresca-Curtin-2019']
# Setting adjustable parameters of the model BCC_screw_Maresca-Curtin-2019.
# {'kink_width': 20.0, 'Delta_V_p_scaler': 1.0, 'Delta_E_p_scaler': 1.0}
# Alloy system: Nb: 0.34 W: 0.33 Mo: 0.33
# grab elemental data for prediction.
# reading datafile ../examples/sample_elements_data.json.
# Setting elemental data of the model BCC_screw_Maresca-Curtin-2019.
# {'Nb': {'a': 3.3, 'Vn': 17.9685, 'b': 2.857883832488647, 'E_f_v': 2.99, 'E_f_si': 5.25, 'Delta_E_p': 0.0345, 'Delta_V_p': 0.02, 'E_k': 0.64}, 'W': {'a': 3.16, 'Vn': 15.777248000000002, 'b': 2.736640275958826, 'E_f_v': 3.5655, 'E_f_si': 9.5417, 'Delta_E_p': 0.1493, 'Delta_V_p': 0.02, 'E_k': 0.9057}, 'Mo': {'a': 3.14, 'Vn': 15.479572000000001, 'b': 2.719319767883137, 'E_f_v': 2.9607, 'E_f_si': 7.3792, 'Delta_E_p': 0.1579, 'Delta_V_p': 0.02, 'E_k': 0.5251}}
# Preparing Calculation -> BCC_screw_Maresca-Curtin-2019.
# Done Calculation. -> BCC_screw_Maresca-Curtin-2019.
# removing BCC_screw_Maresca-Curtin-2019 from the model set.
# Currently using model(s): [].
#       Co    Fe    Ni    Mn    Mo     W    Nb    Zr      T  strain_rate  \
# 0   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN    0.0        0.001
# 1   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN  100.0        0.001
# 2   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN  200.0        0.001
# 3   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN  300.0        0.001
# 4   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN  400.0        0.001
# 5   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN  500.0        0.001
# 6    NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0    0.0        0.001
# 7    NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0  100.0        0.001
# 8    NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0  200.0        0.001
# 9    NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0  300.0        0.001
# 10   NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0  400.0        0.001
# 11   NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0  500.0        0.001
# 12   NaN   NaN   NaN   NaN  33.0  33.0  34.0   NaN    0.0        0.001
# 13   NaN   NaN   NaN   NaN  33.0  33.0  34.0   NaN  100.0        0.001
# 14   NaN   NaN   NaN   NaN  33.0  33.0  34.0   NaN  200.0        0.001
# 15   NaN   NaN   NaN   NaN  33.0  33.0  34.0   NaN  300.0        0.001
# 16   NaN   NaN   NaN   NaN  33.0  33.0  34.0   NaN  400.0        0.001
# 17   NaN   NaN   NaN   NaN  33.0  33.0  34.0   NaN  500.0        0.001
#
#      tau_y structure                          model  \
# 0   126.10       fcc       FCC_Varvenne-Curtin-2016
# 1    91.42       fcc       FCC_Varvenne-Curtin-2016
# 2    71.06       fcc       FCC_Varvenne-Curtin-2016
# 3    57.43       fcc       FCC_Varvenne-Curtin-2016
# 4    44.18       fcc       FCC_Varvenne-Curtin-2016
# 5    33.99       fcc       FCC_Varvenne-Curtin-2016
# 6   569.02       bcc   BCC_edge_Maresca-Curtin-2019
# 7   501.84       bcc   BCC_edge_Maresca-Curtin-2019
# 8   462.37       bcc   BCC_edge_Maresca-Curtin-2019
# 9   429.27       bcc   BCC_edge_Maresca-Curtin-2019
# 10  399.73       bcc   BCC_edge_Maresca-Curtin-2019
# 11  372.57       bcc   BCC_edge_Maresca-Curtin-2019
# 12  906.54       bcc  BCC_screw_Maresca-Curtin-2019
# 13  787.76       bcc  BCC_screw_Maresca-Curtin-2019
# 14  717.99       bcc  BCC_screw_Maresca-Curtin-2019
# 15  659.47       bcc  BCC_screw_Maresca-Curtin-2019
# 16  607.23       bcc  BCC_screw_Maresca-Curtin-2019
# 17  559.22       bcc  BCC_screw_Maresca-Curtin-2019
#
#                                           adjustables
# 0            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 1            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 2            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 3            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 4            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 5            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 6   {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 7   {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 8   {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 9   {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 10  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 11  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 12  {'kink_width': 20.0, 'Delta_V_p_scaler': 1.0, ...
# 13  {'kink_width': 20.0, 'Delta_V_p_scaler': 1.0, ...
# 14  {'kink_width': 20.0, 'Delta_V_p_scaler': 1.0, ...
# 15  {'kink_width': 20.0, 'Delta_V_p_scaler': 1.0, ...
# 16  {'kink_width': 20.0, 'Delta_V_p_scaler': 1.0, ...
# 17  {'kink_width': 20.0, 'Delta_V_p_scaler': 1.0, ...

# %%
# Now, select another model to use: 
print('Example 4')
single_calc.use_model('BCC_screw_Suzuki_RWASM-2020')

# setup another system: TiNbZr
comp_example4 = {'Nb':34,"Ti":33,"Zr":33}
single_calc.set_comp(comp_example4)



# specify the adjustable parameters for the model 
single_calc.set_adjustables(kink_width=1, 
                             tau_i_exponent = 1, 
                             dislocation_density= 4e13, 
                             trial_kappa={'min': 1, 'max': 4, 'inc': 0.5}, 
                             trial_tau_k = 5)

single_calc.grab_data(filein)
print(single_calc.data_of_ssmodels['BCC_screw_Suzuki_RWASM-2020'])

single_calc.calculate()

single_calc.remove_model('BCC_screw_Suzuki_RWASM-2020')

single_calc.reorganize_data()
single_calc.pretty_calc_data
# Out:
# Example 4
# Currently using model(s): ['BCC_screw_Suzuki_RWASM-2020']
# Alloy system: Nb: 0.34 Ti: 0.33 Zr: 0.33
# Setting adjustable parameters of the model BCC_screw_Suzuki_RWASM-2020.
# {'kink_width': 1.0, 'tau_i_exponent': 1.0, 'dislocation_density': 40000000000000.0, 'trial_kappa': {'min': 1.0, 'max': 4.0, 'inc': 0.5}, 'trial_tau_k': 5.0}
# grab elemental data for prediction.
# reading datafile ../examples/sample_elements_data.json.
# Setting elemental data of the model BCC_screw_Suzuki_RWASM-2020.
# {'Nb': {'nu': 0.4, 'G': 38, 'E': 106.4, 'a': 3.3, 'Vn': 17.9685, 'b': 2.857883832488647, 'E_f_v': 2.99, 'E_f_si': 5.25, 'E_w_i': 0.054}, 'Ti': {'nu': 0.32, 'G': 44, 'E': 116.2, 'a': 3.31, 'Vn': 18.1323455, 'b': 2.866544086526492, 'E_f_v': 2.22, 'E_f_si': 2.4, 'E_w_i': -0.028}, 'Zr': {'nu': 0.34, 'G': 33, 'E': 88.4, 'a': 3.58, 'Vn': 22.941356000000003, 'b': 3.10037094554829, 'E_f_v': 1.8, 'E_f_si': 3.5, 'E_w_i': -0.053}}
# Preparing Calculation -> BCC_screw_Suzuki_RWASM-2020.
# /Users/Wendongsheng/project/pySSpredict/pySSpredict/bin/sspredict/make_prediction/models.py:1019: RuntimeWarning: divide by zero encountered in log
#   np.log( (5*np.pi*self.kT)**2 * self.Debye * self.a_p * self.b /((self.G*self.b*self.Delta_V(tau_k_trial,kappa_i))**2 * self.strain_r) )
# /Users/Wendongsheng/project/pySSpredict/pySSpredict/bin/sspredict/make_prediction/models.py:1019: RuntimeWarning: invalid value encountered in multiply
#   np.log( (5*np.pi*self.kT)**2 * self.Debye * self.a_p * self.b /((self.G*self.b*self.Delta_V(tau_k_trial,kappa_i))**2 * self.strain_r) )
# /Users/Wendongsheng/project/pySSpredict/pySSpredict/bin/sspredict/make_prediction/models.py:1002: RuntimeWarning: divide by zero encountered in double_scalars
#   D = 14*self.Debye*self.b**2 * np.exp(-Q/self.kT)
# Done Calculation. -> BCC_screw_Suzuki_RWASM-2020.
# removing BCC_screw_Suzuki_RWASM-2020 from the model set.
# Currently using model(s): [].
#       Co    Fe    Ni    Mn    Mo     W    Nb    Zr    Ti  T_liquidus  \
# 0   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN   NaN         NaN
# 1   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN   NaN         NaN
# 2   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN   NaN         NaN
# 3   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN   NaN         NaN
# 4   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN   NaN         NaN
# 5   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN   NaN         NaN
# 6    NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0   NaN         NaN
# 7    NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0   NaN         NaN
# 8    NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0   NaN         NaN
# 9    NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0   NaN         NaN
# 10   NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0   NaN         NaN
# 11   NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0   NaN         NaN
# 12   NaN   NaN   NaN   NaN  33.0  33.0  34.0   NaN   NaN         NaN
# 13   NaN   NaN   NaN   NaN  33.0  33.0  34.0   NaN   NaN         NaN
# 14   NaN   NaN   NaN   NaN  33.0  33.0  34.0   NaN   NaN         NaN
# 15   NaN   NaN   NaN   NaN  33.0  33.0  34.0   NaN   NaN         NaN
# 16   NaN   NaN   NaN   NaN  33.0  33.0  34.0   NaN   NaN         NaN
# 17   NaN   NaN   NaN   NaN  33.0  33.0  34.0   NaN   NaN         NaN
# 18   NaN   NaN   NaN   NaN   NaN   NaN  34.0  33.0  33.0         NaN
# 19   NaN   NaN   NaN   NaN   NaN   NaN  34.0  33.0  33.0         NaN
# 20   NaN   NaN   NaN   NaN   NaN   NaN  34.0  33.0  33.0         NaN
# 21   NaN   NaN   NaN   NaN   NaN   NaN  34.0  33.0  33.0         NaN
# 22   NaN   NaN   NaN   NaN   NaN   NaN  34.0  33.0  33.0         NaN
# 23   NaN   NaN   NaN   NaN   NaN   NaN  34.0  33.0  33.0         NaN
#
#    jog_activated      T  strain_rate   tau_y structure  \
# 0            NaN    0.0        0.001  126.10       fcc
# 1            NaN  100.0        0.001   91.42       fcc
# 2            NaN  200.0        0.001   71.06       fcc
# 3            NaN  300.0        0.001   57.43       fcc
# 4            NaN  400.0        0.001   44.18       fcc
# 5            NaN  500.0        0.001   33.99       fcc
# 6            NaN    0.0        0.001  569.02       bcc
# 7            NaN  100.0        0.001  501.84       bcc
# 8            NaN  200.0        0.001  462.37       bcc
# 9            NaN  300.0        0.001  429.27       bcc
# 10           NaN  400.0        0.001  399.73       bcc
# 11           NaN  500.0        0.001  372.57       bcc
# 12           NaN    0.0        0.001  906.54       bcc
# 13           NaN  100.0        0.001  787.76       bcc
# 14           NaN  200.0        0.001  717.99       bcc
# 15           NaN  300.0        0.001  659.47       bcc
# 16           NaN  400.0        0.001  607.23       bcc
# 17           NaN  500.0        0.001  559.22       bcc
# 18         False    0.0        0.001   11.23       bcc
# 19         False  100.0        0.001  804.55       bcc
# 20         False  200.0        0.001  479.10       bcc
# 21         False  300.0        0.001  352.54       bcc
# 22         False  400.0        0.001  283.33       bcc
# 23         False  500.0        0.001  238.96       bcc
#
#                             model  \
# 0        FCC_Varvenne-Curtin-2016
# 1        FCC_Varvenne-Curtin-2016
# 2        FCC_Varvenne-Curtin-2016
# 3        FCC_Varvenne-Curtin-2016
# 4        FCC_Varvenne-Curtin-2016
# 5        FCC_Varvenne-Curtin-2016
# 6    BCC_edge_Maresca-Curtin-2019
# 7    BCC_edge_Maresca-Curtin-2019
# 8    BCC_edge_Maresca-Curtin-2019
# 9    BCC_edge_Maresca-Curtin-2019
# 10   BCC_edge_Maresca-Curtin-2019
# 11   BCC_edge_Maresca-Curtin-2019
# 12  BCC_screw_Maresca-Curtin-2019
# 13  BCC_screw_Maresca-Curtin-2019
# 14  BCC_screw_Maresca-Curtin-2019
# 15  BCC_screw_Maresca-Curtin-2019
# 16  BCC_screw_Maresca-Curtin-2019
# 17  BCC_screw_Maresca-Curtin-2019
# 18    BCC_screw_Suzuki_RWASM-2020
# 19    BCC_screw_Suzuki_RWASM-2020
# 20    BCC_screw_Suzuki_RWASM-2020
# 21    BCC_screw_Suzuki_RWASM-2020
# 22    BCC_screw_Suzuki_RWASM-2020
# 23    BCC_screw_Suzuki_RWASM-2020
#
#                                           adjustables
# 0            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 1            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 2            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 3            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 4            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 5            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 6   {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 7   {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 8   {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 9   {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 10  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 11  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 12  {'kink_width': 20.0, 'Delta_V_p_scaler': 1.0, ...
# 13  {'kink_width': 20.0, 'Delta_V_p_scaler': 1.0, ...
# 14  {'kink_width': 20.0, 'Delta_V_p_scaler': 1.0, ...
# 15  {'kink_width': 20.0, 'Delta_V_p_scaler': 1.0, ...
# 16  {'kink_width': 20.0, 'Delta_V_p_scaler': 1.0, ...
# 17  {'kink_width': 20.0, 'Delta_V_p_scaler': 1.0, ...
# 18  {'kink_width': 1.0, 'tau_i_exponent': 1.0, 'di...
# 19  {'kink_width': 1.0, 'tau_i_exponent': 1.0, 'di...
# 20  {'kink_width': 1.0, 'tau_i_exponent': 1.0, 'di...
# 21  {'kink_width': 1.0, 'tau_i_exponent': 1.0, 'di...
# 22  {'kink_width': 1.0, 'tau_i_exponent': 1.0, 'di...
# 23  {'kink_width': 1.0, 'tau_i_exponent': 1.0, 'di...

# %%
print('Example 5')
# specify model to use
single_calc.use_model('FCC_Varvenne-Curtin-2016')

# 3d TM CrFeCoNi + Mo
comp_example5 = {'Co':24,'Fe':24,'Ni':24,'Mn':24,'Mo':4}
# setup the system
single_calc.set_comp(comp_example5)
# specify the adjustable parameters for the model 
single_calc.set_adjustables(f1=0.35, 
                            f2=5.7, 
                            alpha=1/16)

# if not specified, adjustables have default values: 
# single_calc.set_adjustables()

# specify experimental conditions
temperature = 900#np.arange(0,600,100)
strain_r = 0.001
single_calc.set_temp(temperature)
single_calc.set_strain_r(strain_r)
single_calc.exp_conditions()

# get data from user input
single_calc.grab_data(filein)
#print(single_calc.data_of_ssmodels)

# next make prediction
single_calc.calculate()
# if don't want to use model, remove it by
#single_calc.remove_model('FCC_Varvenne-Curtin-2016')
single_calc.reorganize_data()
single_calc.pretty_calc_data
# Out:
# Example 5
# Currently using model(s): ['FCC_Varvenne-Curtin-2016']
# Alloy system: Co: 0.24 Fe: 0.24 Ni: 0.24 Mn: 0.24 Mo: 0.04
# Setting adjustable parameters of the model FCC_Varvenne-Curtin-2016.
# {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# Temperature: [900]
# Strain rate: 0.001
# grab elemental data for prediction.
# reading datafile ../examples/sample_elements_data.json.
# Setting elemental data of the model FCC_Varvenne-Curtin-2016.
# Preparing Calculation -> FCC_Varvenne-Curtin-2016.
# Done Calculation. -> FCC_Varvenne-Curtin-2016.
#       Co    Fe    Ni    Mn    Mo     W    Nb    Zr    Ti  T_liquidus  \
# 0   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN   NaN         NaN
# 1   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN   NaN         NaN
# 2   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN   NaN         NaN
# 3   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN   NaN         NaN
# 4   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN   NaN         NaN
# 5   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN   NaN         NaN
# 6    NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0   NaN         NaN
# 7    NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0   NaN         NaN
# 8    NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0   NaN         NaN
# 9    NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0   NaN         NaN
# 10   NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0   NaN         NaN
# 11   NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0   NaN         NaN
# 12   NaN   NaN   NaN   NaN  33.0  33.0  34.0   NaN   NaN         NaN
# 13   NaN   NaN   NaN   NaN  33.0  33.0  34.0   NaN   NaN         NaN
# 14   NaN   NaN   NaN   NaN  33.0  33.0  34.0   NaN   NaN         NaN
# 15   NaN   NaN   NaN   NaN  33.0  33.0  34.0   NaN   NaN         NaN
# 16   NaN   NaN   NaN   NaN  33.0  33.0  34.0   NaN   NaN         NaN
# 17   NaN   NaN   NaN   NaN  33.0  33.0  34.0   NaN   NaN         NaN
# 18   NaN   NaN   NaN   NaN   NaN   NaN  34.0  33.0  33.0         NaN
# 19   NaN   NaN   NaN   NaN   NaN   NaN  34.0  33.0  33.0         NaN
# 20   NaN   NaN   NaN   NaN   NaN   NaN  34.0  33.0  33.0         NaN
# 21   NaN   NaN   NaN   NaN   NaN   NaN  34.0  33.0  33.0         NaN
# 22   NaN   NaN   NaN   NaN   NaN   NaN  34.0  33.0  33.0         NaN
# 23   NaN   NaN   NaN   NaN   NaN   NaN  34.0  33.0  33.0         NaN
# 24  24.0  24.0  24.0  24.0   4.0   NaN   NaN   NaN   NaN         NaN
#
#    jog_activated      T  strain_rate   tau_y structure  \
# 0            NaN    0.0        0.001  126.10       fcc
# 1            NaN  100.0        0.001   91.42       fcc
# 2            NaN  200.0        0.001   71.06       fcc
# 3            NaN  300.0        0.001   57.43       fcc
# 4            NaN  400.0        0.001   44.18       fcc
# 5            NaN  500.0        0.001   33.99       fcc
# 6            NaN    0.0        0.001  569.02       bcc
# 7            NaN  100.0        0.001  501.84       bcc
# 8            NaN  200.0        0.001  462.37       bcc
# 9            NaN  300.0        0.001  429.27       bcc
# 10           NaN  400.0        0.001  399.73       bcc
# 11           NaN  500.0        0.001  372.57       bcc
# 12           NaN    0.0        0.001  906.54       bcc
# 13           NaN  100.0        0.001  787.76       bcc
# 14           NaN  200.0        0.001  717.99       bcc
# 15           NaN  300.0        0.001  659.47       bcc
# 16           NaN  400.0        0.001  607.23       bcc
# 17           NaN  500.0        0.001  559.22       bcc
# 18         False    0.0        0.001   11.23       bcc
# 19         False  100.0        0.001  804.55       bcc
# 20         False  200.0        0.001  479.10       bcc
# 21         False  300.0        0.001  352.54       bcc
# 22         False  400.0        0.001  283.33       bcc
# 23         False  500.0        0.001  238.96       bcc
# 24           NaN  900.0        0.001   35.11       fcc
#
#                             model  \
# 0        FCC_Varvenne-Curtin-2016
# 1        FCC_Varvenne-Curtin-2016
# 2        FCC_Varvenne-Curtin-2016
# 3        FCC_Varvenne-Curtin-2016
# 4        FCC_Varvenne-Curtin-2016
# 5        FCC_Varvenne-Curtin-2016
# 6    BCC_edge_Maresca-Curtin-2019
# 7    BCC_edge_Maresca-Curtin-2019
# 8    BCC_edge_Maresca-Curtin-2019
# 9    BCC_edge_Maresca-Curtin-2019
# 10   BCC_edge_Maresca-Curtin-2019
# 11   BCC_edge_Maresca-Curtin-2019
# 12  BCC_screw_Maresca-Curtin-2019
# 13  BCC_screw_Maresca-Curtin-2019
# 14  BCC_screw_Maresca-Curtin-2019
# 15  BCC_screw_Maresca-Curtin-2019
# 16  BCC_screw_Maresca-Curtin-2019
# 17  BCC_screw_Maresca-Curtin-2019
# 18    BCC_screw_Suzuki_RWASM-2020
# 19    BCC_screw_Suzuki_RWASM-2020
# 20    BCC_screw_Suzuki_RWASM-2020
# 21    BCC_screw_Suzuki_RWASM-2020
# 22    BCC_screw_Suzuki_RWASM-2020
# 23    BCC_screw_Suzuki_RWASM-2020
# 24       FCC_Varvenne-Curtin-2016
#
#                                           adjustables
# 0            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 1            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 2            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 3            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 4            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 5            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 6   {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 7   {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 8   {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 9   {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 10  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 11  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 12  {'kink_width': 20.0, 'Delta_V_p_scaler': 1.0, ...
# 13  {'kink_width': 20.0, 'Delta_V_p_scaler': 1.0, ...
# 14  {'kink_width': 20.0, 'Delta_V_p_scaler': 1.0, ...
# 15  {'kink_width': 20.0, 'Delta_V_p_scaler': 1.0, ...
# 16  {'kink_width': 20.0, 'Delta_V_p_scaler': 1.0, ...
# 17  {'kink_width': 20.0, 'Delta_V_p_scaler': 1.0, ...
# 18  {'kink_width': 1.0, 'tau_i_exponent': 1.0, 'di...
# 19  {'kink_width': 1.0, 'tau_i_exponent': 1.0, 'di...
# 20  {'kink_width': 1.0, 'tau_i_exponent': 1.0, 'di...
# 21  {'kink_width': 1.0, 'tau_i_exponent': 1.0, 'di...
# 22  {'kink_width': 1.0, 'tau_i_exponent': 1.0, 'di...
# 23  {'kink_width': 1.0, 'tau_i_exponent': 1.0, 'di...
# 24           {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}

# %%
print('BUG test')
# specify model to use
single_calc.use_model(single_calc.ssmodels_all[0])
single_calc.use_model(single_calc.ssmodels_all[1])
single_calc.use_model(single_calc.ssmodels_all[2])
single_calc.use_model(single_calc.ssmodels_all[3])


# 3d TM CrFeCoNi + Mo
comp_example5 = {'Co':24,'Fe':24,'Ni':24,'Mn':24,'Mo':4}
# setup the system
single_calc.set_comp(comp_example5)
# specify the adjustable parameters for the model 
single_calc.set_adjustables(f1=0.35, 
                            f2=5.7, 
                            alpha=1/16)

# if not specified, adjustables have default values: 
# single_calc.set_adjustables()

# specify experimental conditions
temperature = 900#np.arange(0,600,100)
strain_r = 0.001
single_calc.set_temp(temperature)
single_calc.set_strain_r(strain_r)
single_calc.exp_conditions()

# get data from user input
single_calc.grab_data(filein)
#print(single_calc.data_of_ssmodels)

# next make prediction
single_calc.calculate()
# if don't want to use model, remove it by
#single_calc.remove_model('FCC_Varvenne-Curtin-2016')
single_calc.reorganize_data()
single_calc.pretty_calc_data
# Out:
# BUG test
# FCC_Varvenne-Curtin-2016 exists.
# Currently using model(s): ['FCC_Varvenne-Curtin-2016']
# Currently using model(s): ['FCC_Varvenne-Curtin-2016', 'BCC_edge_Maresca-Curtin-2019']
# Currently using model(s): ['FCC_Varvenne-Curtin-2016', 'BCC_edge_Maresca-Curtin-2019', 'BCC_screw_Maresca-Curtin-2019']
# Currently using model(s): ['FCC_Varvenne-Curtin-2016', 'BCC_edge_Maresca-Curtin-2019', 'BCC_screw_Maresca-Curtin-2019', 'BCC_screw_Suzuki_RWASM-2020']
# Alloy system: Co: 0.24 Fe: 0.24 Ni: 0.24 Mn: 0.24 Mo: 0.04
# Setting adjustable parameters of the model FCC_Varvenne-Curtin-2016.
# {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# Setting adjustable parameters of the model BCC_edge_Maresca-Curtin-2019.
# {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# Setting adjustable parameters of the model BCC_screw_Maresca-Curtin-2019.
# {'kink_width': 10, 'Delta_V_p_scaler': 1, 'Delta_E_p_scaler': 1}
# Setting adjustable parameters of the model BCC_screw_Suzuki_RWASM-2020.
# {'kink_width': 10, 'tau_i_exponent': 1, 'dislocation_density': 40000000000000.0, 'trial_kappa': {'min': 1, 'max': 4, 'inc': 0.5}, 'trial_tau_k': 5}
# Temperature: [900]
# Strain rate: 0.001
# grab elemental data for prediction.
# reading datafile ../examples/sample_elements_data.json.
# Setting elemental data of the model FCC_Varvenne-Curtin-2016.
# Setting elemental data of the model BCC_edge_Maresca-Curtin-2019.
# Setting elemental data of the model BCC_screw_Maresca-Curtin-2019.
# Failed to fetch data for ['Co', 'Fe', 'Ni', 'Mn', 'Mo']
# Make sure data file contains:
# 1. "structure",
# 2. "Vn" or "a" or "b",
#  3. "E_f_v" "E_f_si" "Delta_E_p" "E_k"
#
# Setting elemental data of the model BCC_screw_Suzuki_RWASM-2020.
# Failed to fetch data for ['Co', 'Fe', 'Ni', 'Mn', 'Mo']
# Make sure data file contains:
# 1. "structure",
# 2. "Vn" or "a" or "b", and elastic moduli
#  3. "E_f_v" "E_f_si" "E_w_i"
#
# Preparing Calculation -> FCC_Varvenne-Curtin-2016.
# Done Calculation. -> FCC_Varvenne-Curtin-2016.
# Preparing Calculation -> BCC_edge_Maresca-Curtin-2019.
# Done Calculation. -> BCC_edge_Maresca-Curtin-2019.
# Preparing Calculation -> BCC_screw_Maresca-Curtin-2019.
# NO Calculation Performed. Check your data -> BCC_screw_Maresca-Curtin-2019.
# Preparing Calculation -> BCC_screw_Suzuki_RWASM-2020.
# NO Calculation Performed. Check your data -> BCC_screw_Suzuki_RWASM-2020.
#       Co    Fe    Ni    Mn    Mo     W    Nb    Zr    Ti  T_liquidus  \
# 0   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN   NaN         NaN
# 1   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN   NaN         NaN
# 2   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN   NaN         NaN
# 3   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN   NaN         NaN
# 4   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN   NaN         NaN
# 5   25.0  25.0  25.0  25.0   NaN   NaN   NaN   NaN   NaN         NaN
# 6    NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0   NaN         NaN
# 7    NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0   NaN         NaN
# 8    NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0   NaN         NaN
# 9    NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0   NaN         NaN
# 10   NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0   NaN         NaN
# 11   NaN   NaN   NaN   NaN  25.0  25.0  25.0  25.0   NaN         NaN
# 12   NaN   NaN   NaN   NaN  33.0  33.0  34.0   NaN   NaN         NaN
# 13   NaN   NaN   NaN   NaN  33.0  33.0  34.0   NaN   NaN         NaN
# 14   NaN   NaN   NaN   NaN  33.0  33.0  34.0   NaN   NaN         NaN
# 15   NaN   NaN   NaN   NaN  33.0  33.0  34.0   NaN   NaN         NaN
# 16   NaN   NaN   NaN   NaN  33.0  33.0  34.0   NaN   NaN         NaN
# 17   NaN   NaN   NaN   NaN  33.0  33.0  34.0   NaN   NaN         NaN
# 18   NaN   NaN   NaN   NaN   NaN   NaN  34.0  33.0  33.0         NaN
# 19   NaN   NaN   NaN   NaN   NaN   NaN  34.0  33.0  33.0         NaN
# 20   NaN   NaN   NaN   NaN   NaN   NaN  34.0  33.0  33.0         NaN
# 21   NaN   NaN   NaN   NaN   NaN   NaN  34.0  33.0  33.0         NaN
# 22   NaN   NaN   NaN   NaN   NaN   NaN  34.0  33.0  33.0         NaN
# 23   NaN   NaN   NaN   NaN   NaN   NaN  34.0  33.0  33.0         NaN
# 25  24.0  24.0  24.0  24.0   4.0   NaN   NaN   NaN   NaN         NaN
# 26  24.0  24.0  24.0  24.0   4.0   NaN   NaN   NaN   NaN         NaN
#
#    jog_activated      T  strain_rate   tau_y structure  \
# 0            NaN    0.0        0.001  126.10       fcc
# 1            NaN  100.0        0.001   91.42       fcc
# 2            NaN  200.0        0.001   71.06       fcc
# 3            NaN  300.0        0.001   57.43       fcc
# 4            NaN  400.0        0.001   44.18       fcc
# 5            NaN  500.0        0.001   33.99       fcc
# 6            NaN    0.0        0.001  569.02       bcc
# 7            NaN  100.0        0.001  501.84       bcc
# 8            NaN  200.0        0.001  462.37       bcc
# 9            NaN  300.0        0.001  429.27       bcc
# 10           NaN  400.0        0.001  399.73       bcc
# 11           NaN  500.0        0.001  372.57       bcc
# 12           NaN    0.0        0.001  906.54       bcc
# 13           NaN  100.0        0.001  787.76       bcc
# 14           NaN  200.0        0.001  717.99       bcc
# 15           NaN  300.0        0.001  659.47       bcc
# 16           NaN  400.0        0.001  607.23       bcc
# 17           NaN  500.0        0.001  559.22       bcc
# 18         False    0.0        0.001   11.23       bcc
# 19         False  100.0        0.001  804.55       bcc
# 20         False  200.0        0.001  479.10       bcc
# 21         False  300.0        0.001  352.54       bcc
# 22         False  400.0        0.001  283.33       bcc
# 23         False  500.0        0.001  238.96       bcc
# 25           NaN  900.0        0.001   35.11       fcc
# 26           NaN  900.0        0.001   37.35       bcc
#
#                             model  \
# 0        FCC_Varvenne-Curtin-2016
# 1        FCC_Varvenne-Curtin-2016
# 2        FCC_Varvenne-Curtin-2016
# 3        FCC_Varvenne-Curtin-2016
# 4        FCC_Varvenne-Curtin-2016
# 5        FCC_Varvenne-Curtin-2016
# 6    BCC_edge_Maresca-Curtin-2019
# 7    BCC_edge_Maresca-Curtin-2019
# 8    BCC_edge_Maresca-Curtin-2019
# 9    BCC_edge_Maresca-Curtin-2019
# 10   BCC_edge_Maresca-Curtin-2019
# 11   BCC_edge_Maresca-Curtin-2019
# 12  BCC_screw_Maresca-Curtin-2019
# 13  BCC_screw_Maresca-Curtin-2019
# 14  BCC_screw_Maresca-Curtin-2019
# 15  BCC_screw_Maresca-Curtin-2019
# 16  BCC_screw_Maresca-Curtin-2019
# 17  BCC_screw_Maresca-Curtin-2019
# 18    BCC_screw_Suzuki_RWASM-2020
# 19    BCC_screw_Suzuki_RWASM-2020
# 20    BCC_screw_Suzuki_RWASM-2020
# 21    BCC_screw_Suzuki_RWASM-2020
# 22    BCC_screw_Suzuki_RWASM-2020
# 23    BCC_screw_Suzuki_RWASM-2020
# 25       FCC_Varvenne-Curtin-2016
# 26   BCC_edge_Maresca-Curtin-2019
#
#                                           adjustables
# 0            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 1            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 2            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 3            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 4            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 5            {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 6   {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 7   {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 8   {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 9   {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 10  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 11  {'f1': 0.35, 'f2': 5.7, 'alpha': 0.08333333333...
# 12  {'kink_width': 20.0, 'Delta_V_p_scaler': 1.0, ...
# 13  {'kink_width': 20.0, 'Delta_V_p_scaler': 1.0, ...
# 14  {'kink_width': 20.0, 'Delta_V_p_scaler': 1.0, ...
# 15  {'kink_width': 20.0, 'Delta_V_p_scaler': 1.0, ...
# 16  {'kink_width': 20.0, 'Delta_V_p_scaler': 1.0, ...
# 17  {'kink_width': 20.0, 'Delta_V_p_scaler': 1.0, ...
# 18  {'kink_width': 1.0, 'tau_i_exponent': 1.0, 'di...
# 19  {'kink_width': 1.0, 'tau_i_exponent': 1.0, 'di...
# 20  {'kink_width': 1.0, 'tau_i_exponent': 1.0, 'di...
# 21  {'kink_width': 1.0, 'tau_i_exponent': 1.0, 'di...
# 22  {'kink_width': 1.0, 'tau_i_exponent': 1.0, 'di...
# 23  {'kink_width': 1.0, 'tau_i_exponent': 1.0, 'di...
# 25           {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
# 26           {'f1': 0.35, 'f2': 5.7, 'alpha': 0.0625}
